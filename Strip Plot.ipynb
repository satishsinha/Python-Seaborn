# %%
## Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Import data frame
data = pd.read_excel('supermarket_sales.xlsx')

# %%
## Complete information of Data Frame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.head(2)
# Out:
#     Invoice ID Branch      City Customer type  Gender         Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female   Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female  Fashion_accessories
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
#
#        Payment    cogs  gross margin percentage  gross income  Rating
# 0  Credit card  164.52                 4.761905         8.226     5.9
# 1      Ewallet   57.92                 4.761905         2.896     4.5

# %%
## create a basic Strip Plot
plt.figure(figsize=(8, 5))
sns.stripplot(y='Total',data=data)
# Out:
# <Axes: ylabel='Total'>

# %%
## create a basic Strip Plot
plt.figure(figsize=(8, 5))
sns.stripplot(x='Gender', y='cogs',data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='cogs'>

# %%
## Expand markers in STRIP PLOT using 'jitter'
plt.figure(figsize=(8, 5))
sns.stripplot(y='Unit price',data=data, jitter=3)
# Out:
# <Axes: ylabel='Unit price'>

# %%
## Draw line around the point using 'LINEWIDTH'
plt.figure(figsize=(8, 5))
sns.stripplot(y='Unit price',data=data, linewidth=0.1)
# Out:
# <Axes: ylabel='Unit price'>

# %%
plt.figure(figsize=(8, 5))
sns.stripplot(y='Unit price',data=data, linewidth=1)
# Out:
# <Axes: ylabel='Unit price'>

# %%
data.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %%
## Include 3rd categorical value with hue
plt.figure(figsize=(8, 5))
sns.stripplot(x= 'Customer type', y='Unit price', hue='Gender', data=data, jitter=0.3, linewidth=1)
# Out:
# <Axes: xlabel='Customer type', ylabel='Unit price'>

# %%
## Separate each level of hue using 'DODGE'
plt.figure(figsize=(8, 5))
sns.stripplot(x= 'Customer type', y='Unit price', hue='Gender', data=data, jitter=0.3, linewidth=1, dodge=True)
# Out:
# <Axes: xlabel='Customer type', ylabel='Unit price'>

# %%
## Draw the strip on the top of VIOLIN PLOT
plt.figure(figsize=(8, 5))
sns.stripplot(x='Payment', y='Total',data=data, linewidth=0.1, jitter=0.4)
sns.violinplot(x='Payment', y='Total',data=data, linewidth=0.9, color='gray')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
## Draw the strip on the top of BOX PLOT
plt.figure(figsize=(8, 5))
sns.stripplot(x='Payment', y='Total',data=data, linewidth=0.1, jitter=0.4)
sns.boxplot(x='Payment', y='Total',data=data, linewidth=0.9, color='gray')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>
